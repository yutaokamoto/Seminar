# %% [markdown]
# # ソルバーの実行

# %% [markdown]
# ## 準備

# %%
import gurobi as gp
import datetime
import random
import numpy as np
random.seed(1)
import os

# %%
def group(i,l): # アイテムiがグループGに属しているかどうかをバイナリで返す関数
    for j in l:
        for k in j:
            if k==i:
                return 1
            else:
                return 0

# %%
def group(i,l): # アイテムiがグループGに属しているかどうかをバイナリで返す関数
    if i in l:
        return 1
    else:
        return 0

# %%
tl = 1000

# %%
def solve(moel_name,n,w,C,E,M,r,bin_cost,tl):
    model = gp.Model(name = model_name)
    model.setParam('TimeLimit', tl) #制限時間
    #解
    ans_x = {}
    ans_y = {}
    ans_b = {}
    #定数定義
    m = len(M)
    z = {}
    #変数定義
    x = {}
    y = {}
    b = {}
    for l in range(m):
        for k in range(n):
            y[k] = model.addVar(lb=0, ub=1, vtype='B', name='y[%s]'%k)
            b[k,l] = model.addVar(lb=0, ub=1, vtype='B', name='b[%s,%s]'%(k,l))
            for i in range(n):
                x[i,k] = model.addVar(lb=0, ub=1, vtype='B', name='x[%s,%s]'%(i,k))
                z[i,l] = group(i,M[l])
                #if l==0 and z[i,l]==1:
                    #print(i)
                
    #print(z)
    model.update()
        
    #目的関数
    ##model.setObjective(gp.quicksum(bin_cost*y[k] for k in range(n)) + gp.quicksum(r[l]*gp.quicksum(b[k,l] for k in range(n)) for l in range(m)) - sum(r), sense=gp.GRB.MINIMIZE)
    model.setObjective(gp.quicksum(y[k] for k in range(n)) + gp.quicksum(gp.quicksum(r[l]*b[k,l] for l in range(m)) for k in range(n)) - sum(r), sense=gp.GRB.MINIMIZE)

    #制約式
    for k in range(n):
        model.addConstr(gp.quicksum(w[i]*x[i,k] for i in range(n))<=C*y[k], 'Binlimit[%s]'%k) #ビンの容量を超えない
    for i in range(n):
        model.addConstr(gp.quicksum(x[i,k] for k in range(n))==1, 'Assign[%s]'%i) #すべてのアイテムはビンに詰め込まれている
        for k in range(n):
            model.addConstr(x[i,k]<=y[k], 'Strong[%s,%s]'%(i,k)) #強い定式化
    for e in E:
        for k in range(n):
            model.addConstr(x[e[0],k]+x[e[1],k]<=1,'Conflict[%s,%s]'%(e[0],e[1])) #コンフリクト
    for k in range(n):
        for l in range(m):
            for j in range(n):
                model.addConstr(b[k,l]>=x[j,k]*z[j,l],'Group[%s]'%l) #同じグループに属するアイテムは同じビンに割り当てられる
    
    #解の出力
    ##print("↓点線の間に、Gurobi Optimizerからログが出力")
    ##print("-" * 100)

    model.optimize()
    
    if model.Status == gp.GRB.INFEASIBLE:
        pass
    else:
        model.write(f"{model_name}.sol")
    
    ##print("-" * 100)
    ##print()
    
    """if model.Status == gp.GRB.OPTIMAL:
        for v in model.getVars():
            if "x" in v.varName:
                #print("%s = %g"%(v.varName,v.x))
                ans_x[v.varName] = int(v.x)
            if "y" in v.varName:
                ans_y[v.varName] = int(v.x)
            if "b" in v.varName:
                ans_b[v.varName] = int(v.x)

        #print('Opt Value = ', model.ObjVal)
        print("x",ans_x)
        print("bin\t",sum(ans_y.values()))
        print("penalty\t",sum(ans_b.values())*r[0])
        print("Objective value\t",sum(ans_y.values())+(sum(ans_b.values()))*r[0]-sum(r))

        return model.ObjVal"""

# %%
#入力, 出力を書き出す階層を指定
path = os.path.abspath(".")
path
# Out:
# '/Users/yutaokamoto/Desktop/yutaokamoto_mac/Seminar/benchmark'

# %%
for instance_scale in ["w120","w250","w500"]:
    for instance_number in range(10):
        for density in range(10):
            
            if (instance_number==0):################################
                
                n = 0
                V = []
                C = 150
                w = []
                E = []
                M = []
                group_split_cost = 1
                r = []
                bin_cost = 5
                ans_x = []
                ans_y = []
                
                file_input = path + "/" + "input" + "/" + str("i"+str(instance_scale[1:])) + "_"  + str("n"+str(instance_number)) + "_"  + str("d"+str(int(density*10))) + ".txt" #インスタンスの規模_インスタンスの番号_グラフの密度
                with open(file_input,mode="r") as f:
                    for line in f:
                        if "Number of items\t" in line:
                            n = int(line.split("\t")[-2])
                            V = list(range(n))
                        elif "Capacity of bins\t" in line:
                            C = int(line.split("\t")[-2])
                        elif "w\t" in line:
                            w.append(int(line.split("\t")[-1]))
                        elif "e\t" in line:
                            E.append(tuple(map(int,line.split("\t")[-1].rstrip("\n").strip("(").strip(")").split(","))))
                        elif "g\t" in line:
                            M.append(tuple(map(int,line.split("\t")[-1].rstrip("\n").strip("(").strip(")").strip(",").split(","))))
                        elif "Costs of spliting groups\t" in line:
                            r = [int(i) for i in line.split("\t")[-2][1:-1].split(",")]
                        elif "Costs of using bins\t" in line:
                            bin_cost = int(line.split("\t")[-2])
                            
                #print(M[0])
                
                #コンフリクト
                conf={}
                n_conf = len(E)
                for i in range(n_conf):
                    temp = [0]*n
                    temp[E[i][0]-1] = 1
                    temp[E[i][1]-1] = 1
                    conf[f"conf{i}"] = temp

                file_output =  path + "/" + "output" + "/" + "Gurobi" + "/" + str("i"+str(instance_scale[1:])) + "_"  + str("n"+str(instance_number)) + "_"  + str("d"+str(int(density*10))) + "_" + str(tl) + "s"# + ".txt"
                model_name = str(file_output)

                objval = 0
                r = list(map(lambda x:x/bin_cost,r))
                bin_cost = bin_cost/bin_cost
                objval = solve(model_name,n,w,C,E,M,r,bin_cost,tl)
                
                """file_output =  path + "/" + "output" + "/" + "Gurobi" + "/" + str("i"+str(instance_scale[1:])) + "_"  + str("n"+str(instance_number)) + "_"  + str("d"+str(int(density*10))) + "_" + str(tl) + "s" + ".txt"
                with open(file_output,mode="w") as f:
                    f.write("Object value\t"+str(objval)+"\n\n")"""
# Out:
# Academic license - for non-commercial use only
# Changed value of parameter TimeLimit to 1000.0
#    Prev: 1e+100  Min: 0.0  Max: 1e+100  Default: 1e+100
# Optimize a model with 129840 rows, 117120 columns and 187320 nonzeros
# Variable types: 0 continuous, 117120 integer (117120 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+02]
#   Objective range  [2e-01, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 105.0000000
# Presolve removed 107400 rows and 101880 columns
# Presolve time: 1.64s
# Presolved: 22440 rows, 15240 columns, 117360 nonzeros
# Variable types: 0 continuous, 15240 integer (15240 binary)
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
# Concurrent spin time: 1.55s
#
# Solved with primal simplex
#
# Root relaxation: objective 4.945333e+01, 14461 iterations, 4.49 seconds
# Total elapsed time = 12.07s
# Total elapsed time = 19.42s
# Total elapsed time = 23.05s
# Total elapsed time = 27.76s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0
#   1185   859 infeasible   29        54.60000   50.52000  7.47%  1615  976s
#   1199   866   50.52570   30  339   54.60000   50.52000  7.47%  1653  984s
#   1217   876 infeasible   31        54.60000   50.52000  7.47%  1653  993s
#   1234   879   50.63108   32  313   54.60000   50.52000  7.47%  1671 1000s
#
# Cutting planes:
#   Gomory: 65
#   Cover: 5
#   Clique: 12
#   MIR: 33
#   StrongCG: 27
#   Flow cover: 24
#   GUB cover: 14
#   Zero half: 7
#
# Explored 1248 nodes (2854079 simplex iterations) in 1000.05 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 5: 54.6 54.8 55.2 ... 106
#
# Time limit reached
# Best objective 5.460000000000e+01, best bound 5.060000000000e+01, gap 7.3260%
# Warning: variables 0 and 14640 have the same name "y[0]"
# Warning: default variable names used to write solution file
# Changed value of parameter TimeLimit to 1000.0
#    Prev: 1e+100  Min: 0.0  Max: 1e+100  Default: 1e+100
# Optimize a model with 277440 rows, 117120 columns and 482520 nonzeros
# Variable types: 0 continuous, 117120 integer (117120 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+02]
#   Objective range  [2e-01, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 109.0000000
# Presolve removed 258960 rows and 101880 columns
# Presolve time: 2.34s
# Presolved: 18480 rows, 15240 columns, 206990 nonzeros
# Variable types: 0 continuous, 15240 integer (15240 binary)
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#    23685    5.1123347e+01   0.000000e+00   4.376980e+04      5s
#    26023    5.1053333e+01   0.000000e+00   0.000000e+00      6s
# Concurrent spin time: 0.00s
#
# Solved with primal simplex
#
# Root relaxation: objective 5.105333e+01, 26023 iterations, 3.57 seconds
# Total elapsed time = 11.31s
# Total elapsed time = 20.66s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   51.05333    0  408  109.00000   51.05333  53.2%     -   24s
# H    0     0                      60.8000000   51.05333  16.0%     -   24s
# H    0     0                      57.2000000   51.05333  10.7%     -   42s
# H    0     0                      56.8000000   51.05333  10.1%     -   43s
#      0     0   51.05333    0  560   56.80000   51.05333  10.1%     -   50s
#      0     0   51.05333    0  669   56.80000   51.05333  10.1%     -   56s
#      0     0   51.05333    0  381   56.80000   51.05333  10.1%     -   91s
#      0     0   51.05333    0  493   56.80000   51.05333  10.1%     -   94s
# H    0     0                      56.4000000   51.05333  9.48%     -  124s
#      0     0   51.05333    0  466   56.40000   51.05333  9.48%     -  124s
#      0     0   51.05333    0  588   56.40000   51.05333  9.48%     -  126s
#      0     0   51.05333    0  370   56.40000   51.05333  9.48%     -  156s
#      0     0   51.05333    0  370   56.40000   51.05333  9.48%     -  162s
#      0     2   51.05333    0  370   56.40000   51.05333  9.48%     -  189s
#      1     4   51.05333    1  518   56.40000   51.05333  9.48% 26967  191s
#     11     8     cutoff    4        56.40000   51.05333  9.48%  4204  195s
#     29    12 infeasible    6        56.40000   51.05333  9.48%  3303  235s
# H   30    12                      56.2000000   51.05333  9.16%  3193  235s
#     56    16 infeasible   10        56.20000   51.05333  9.16%  2807  241s
#     79    22 infeasible   14        56.20000   51.05333  9.16%  2591  245s
#    131    27 infeasible   21        56.20000   51.05333  9.16%  2056  251s
#    209    33 infeasible   28        56.20000   51.05333  9.16%  1631  257s
#    254    36   51.05333   34  397   56.20000   51.05333  9.16%  1493  260s
#    328    55 infeasible   43        56.20000   51.05333  9.16%  1406  266s
#    372    74   51.80000   50  296   56.20000   51.05333  9.16%  1437  270s
#    435   127   52.80000   55  367   56.20000   51.05333  9.16%  1592  278s
#    474   175   51.80000   58  308   56.20000   51.05333  9.16%  1665  282s
#    514   211   52.00000   63  218   56.20000   51.05333  9.16%  1761  287s
#    577   276   52.20000   72  239   56.20000   51.05333  9.16%  1805  318s
#   1044   634   59.23887  135  315   60.80000   55.80000  8.22%   989  785s
#   1047   637   57.17497   50  453   60.80000   55.80000  8.22%  1389  815s
#   1048   638   59.65149  197  400   60.80000   55.80000  8.22%  1388  828s
#   1049   639   58.83374   86  504   60.80000   55.80000  8.22%  1387  832s
#   1050   639   55.80000    5  333   60.80000   55.80000  8.22%  1385  847s
#   1052   641   58.44899   74  288   60.80000   55.80000  8.22%  1383  861s
#   1054   642   59.98959  106  327   60.80000   55.80000  8.22%  1380  870s
#   1056   643   58.65290   90  352   60.80000   55.80000  8.22%  1377  883s
#   1057   644   60.00000  172  416   60.80000   55.80000  8.22%  1376  885s
#   1058   645   57.96281   69  292   60.80000   55.80000  8.22%  1375  896s
#   1060   646   59.80000  152  291   60.80000   55.80000  8.22%  1372  909s
#   1061   647   57.76611   59  404   60.80000   55.80000  8.22%  1371  911s
#   1062   647   59.20000  126  289   60.80000   55.80000  8.22%  1370  923s
#   1064   649   59.20000  124  261   60.80000   55.80000  8.22%  1367  933s
#   1065   649   55.80000   24  408   60.80000   55.80000  8.22%  1366  935s
#   1066   650   59.23887  135  313   60.80000   55.80000  8.22%  1364  953s
#   1067   651   58.18278   70  313   60.80000   55.80000  8.22%  1363  955s
#   1068   651   58.72205  106  313   60.80000   55.80000  8.22%  1362  983s
#   1069   653 infeasible   26        60.80000   55.80000  8.22%   787 1000s
#
# Cutting planes:
#   Gomory: 15
#   Cover: 2
#   MIR: 21
#   StrongCG: 20
#   Flow cover: 7
#   GUB cover: 8
#   Zero half: 11
#
# Explored 1071 nodes (2251562 simplex iterations) in 1000.14 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 8: 60.8 61 61.2 ... 113.8
#
# Time limit reached
# Best objective 6.080000000000e+01, best bound 5.580000000000e+01, gap 8.2237%
# Warning: variables 0 and 14640 have the same name "y[0]"
# Warning: default variable names used to write solution file
# Changed value of parameter TimeLimit to 1000.0
#    Prev: 1e+100  Min: 0.0  Max: 1e+100  Default: 1e+100
# Optimize a model with 561600 rows, 117120 columns and 1050840 nonzeros
# Variable types: 0 continuous, 117120 integer (117120 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+02]
#   Objective range  [2e-01, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 118.2000000
# Presolve removed 541875 rows and 101880 columns (presolve time = 5s) ...
# Presolve removed 542118 rows and 101880 columns
# Presolve time: 7.88s
# Presolved: 19482 rows, 15240 columns, 502424 nonzeros
# Variable types: 0 continuous, 15240 integer (15240 binary)
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0   -1.2000000e+00   4.236250e+02   4.922195e+09      8s
#    14517    7.1143567e+01   0.000000e+00   2.028259e+03     10s
#    24149    6.9804767e+01   0.000000e+00   3.386666e+03     15s
#    26939    6.9800000e+01   0.000000e+00   0.000000e+00     17s
# Concurrent spin time: 0.00s
#
# Solved with primal simplex
#
# Root relaxation: objective 6.980000e+01, 26939 iterations, 9.15 seconds
# Total elapsed time = 24.10s
# Total elapsed time = 32.86s
# Total elapsed time = 35.92s
# Total elapsed time = 40.48s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   69.80000    0  241  118.20000   69.80000  40.9%     -   42s
# H    0     0                      77.2000000   69.80000  9.59%     -   42s
# H    0     0                      74.2000000   69.80000  5.93%     -   47s
# H    0     0                      73.8000000   69.80000  5.42%     -   48s
#      0     0   69.80000    0  431   73.80000   69.80000  5.42%     -   51s
#      0     0   69.80000    0  428   73.80000   69.80000  5.42%     -   59s
# ...
# Presolve removed 37593299 rows and 2505000 columns (presolve time = 770s) ...
# Presolve removed 37611700 rows and 2505000 columns (presolve time = 775s) ...
# Presolve removed 37632272 rows and 2505000 columns (presolve time = 780s) ...
# Presolve removed 37644678 rows and 2505000 columns (presolve time = 785s) ...
# Presolve removed 37657564 rows and 2505000 columns (presolve time = 790s) ...
# Presolve removed 37682040 rows and 2505000 columns (presolve time = 795s) ...
# Presolve removed 37711056 rows and 2505000 columns (presolve time = 800s) ...
# Presolve removed 37737448 rows and 2505000 columns (presolve time = 805s) ...
# Presolve removed 37762072 rows and 2505000 columns (presolve time = 810s) ...
# Presolve removed 37787746 rows and 2505000 columns (presolve time = 815s) ...
# Presolve removed 37806706 rows and 2505000 columns (presolve time = 820s) ...
# Presolve removed 37833447 rows and 2505000 columns (presolve time = 825s) ...
# Presolve removed 37853178 rows and 2505000 columns (presolve time = 830s) ...
# Presolve removed 37869872 rows and 2505000 columns (presolve time = 835s) ...
# Presolve removed 37890178 rows and 2505000 columns (presolve time = 840s) ...
# Presolve removed 37904674 rows and 2505000 columns (presolve time = 845s) ...
# Presolve removed 37920650 rows and 2505000 columns (presolve time = 850s) ...
# Presolve removed 37938086 rows and 2505000 columns (presolve time = 855s) ...
# Presolve removed 37960652 rows and 2505000 columns (presolve time = 860s) ...
# Presolve removed 37979190 rows and 2505000 columns (presolve time = 865s) ...
# Presolve removed 38009090 rows and 2505000 columns (presolve time = 870s) ...
# Presolve removed 38044588 rows and 2505000 columns (presolve time = 875s) ...
# Presolve removed 38084097 rows and 2505000 columns (presolve time = 880s) ...
# Presolve removed 38130520 rows and 2505000 columns (presolve time = 885s) ...
# Presolve removed 38131052 rows and 2505000 columns (presolve time = 890s) ...
# Presolve removed 38131570 rows and 2505000 columns (presolve time = 895s) ...
# Presolve removed 38132088 rows and 2505000 columns (presolve time = 900s) ...
# Presolve removed 38132581 rows and 2505000 columns (presolve time = 905s) ...
# Presolve removed 38133089 rows and 2505000 columns (presolve time = 910s) ...
# Presolve removed 38133586 rows and 2505000 columns (presolve time = 915s) ...
# Presolve removed 38134055 rows and 2505000 columns (presolve time = 920s) ...
# Presolve removed 38134208 rows and 2505000 columns (presolve time = 925s) ...
# Presolve removed 38134208 rows and 2505000 columns (presolve time = 930s) ...
# Presolve removed 38134208 rows and 2505000 columns (presolve time = 935s) ...
# Presolve removed 38134208 rows and 2505000 columns (presolve time = 940s) ...
# Presolve removed 38134208 rows and 2505000 columns (presolve time = 945s) ...
# Presolve removed 38134208 rows and 2505000 columns (presolve time = 950s) ...
# Presolve removed 38134208 rows and 2505000 columns (presolve time = 955s) ...
# Presolve removed 38134208 rows and 2505000 columns (presolve time = 960s) ...
# Presolve removed 38134208 rows and 2505000 columns (presolve time = 965s) ...
# Presolve removed 38134208 rows and 2505000 columns (presolve time = 970s) ...
# Presolve removed 38134208 rows and 2505000 columns (presolve time = 975s) ...
# Presolve removed 38134208 rows and 2505000 columns
# Presolve time: 979.02s
#
# Explored 0 nodes (0 simplex iterations) in 1005.82 seconds
# Thread count was 1 (of 8 available processors)
#
# Solution count 1: 516.6
#
# Time limit reached
# Best objective 5.166000000000e+02, best bound -, gap -
# Warning: variables 0 and 251000 have the same name "y[0]"
# Warning: default variable names used to write solution file
# Changed value of parameter TimeLimit to 1000.0
#    Prev: 1e+100  Min: 0.0  Max: 1e+100  Default: 1e+100
# Optimize a model with 54548500 rows, 2761000 columns and 107095500 nonzeros
# Variable types: 0 continuous, 2761000 integer (2761000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+02]
#   Objective range  [2e-01, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 548.2000000
# Presolve removed 0 rows and 0 columns (presolve time = 33s) ...
# Presolve removed 2500000 rows and 2505000 columns (presolve time = 43s) ...
# Presolve removed 2500000 rows and 2505000 columns (presolve time = 54s) ...
# Presolve removed 2500000 rows and 2505000 columns (presolve time = 205s) ...
# Presolve removed 2500000 rows and 2505000 columns (presolve time = 269s) ...
# Presolve removed 2500000 rows and 2505000 columns (presolve time = 270s) ...
# Presolve removed 2500000 rows and 2505000 columns (presolve time = 278s) ...
# Presolve removed 2500000 rows and 2505000 columns (presolve time = 280s) ...
# Presolve removed 2500000 rows and 2505000 columns (presolve time = 285s) ...
# Presolve removed 44989500 rows and 2505000 columns (presolve time = 314s) ...
# Presolve removed 44990774 rows and 2505000 columns (presolve time = 315s) ...
# Presolve removed 44993000 rows and 2505000 columns (presolve time = 320s) ...
# Presolve removed 44994663 rows and 2505000 columns (presolve time = 325s) ...
# Presolve removed 44997125 rows and 2505000 columns (presolve time = 330s) ...
# Presolve removed 45009084 rows and 2505000 columns (presolve time = 335s) ...
# Presolve removed 45021097 rows and 2505000 columns (presolve time = 340s) ...
# Presolve removed 45024938 rows and 2505000 columns (presolve time = 345s) ...
# Presolve removed 45032721 rows and 2505000 columns (presolve time = 350s) ...
# Presolve removed 45053398 rows and 2505000 columns (presolve time = 355s) ...
# Presolve removed 45074766 rows and 2505000 columns (presolve time = 360s) ...
# Presolve removed 45086442 rows and 2505000 columns (presolve time = 365s) ...
# Presolve removed 45110900 rows and 2505000 columns (presolve time = 370s) ...
# Presolve removed 45121332 rows and 2505000 columns (presolve time = 375s) ...
# Presolve removed 45138808 rows and 2505000 columns (presolve time = 380s) ...
# Presolve removed 45157845 rows and 2505000 columns (presolve time = 385s) ...
# Presolve removed 45183750 rows and 2505000 columns (presolve time = 390s) ...
# Presolve removed 45217440 rows and 2505000 columns (presolve time = 395s) ...
# Presolve removed 45241200 rows and 2505000 columns (presolve time = 400s) ...
# Presolve removed 45259688 rows and 2505000 columns (presolve time = 405s) ...
# Presolve removed 45290120 rows and 2505000 columns (presolve time = 410s) ...
# Presolve removed 45312934 rows and 2505000 columns (presolve time = 415s) ...
# Presolve removed 45333120 rows and 2505000 columns (presolve time = 420s) ...
# Presolve removed 45367931 rows and 2505000 columns (presolve time = 425s) ...
# Presolve removed 45404657 rows and 2505000 columns (presolve time = 430s) ...
# Presolve removed 45438608 rows and 2505000 columns (presolve time = 435s) ...
# Presolve removed 45460532 rows and 2505000 columns (presolve time = 440s) ...
# Presolve removed 45482932 rows and 2505000 columns (presolve time = 445s) ...
# Presolve removed 45522787 rows and 2505000 columns (presolve time = 450s) ...
# Presolve removed 45567152 rows and 2505000 columns (presolve time = 455s) ...
# Presolve removed 45604083 rows and 2505000 columns (presolve time = 460s) ...
# Presolve removed 45630732 rows and 2505000 columns (presolve time = 465s) ...
# Presolve removed 45679766 rows and 2505000 columns (presolve time = 470s) ...
# Presolve removed 45735294 rows and 2505000 columns (presolve time = 475s) ...
# Presolve removed 45790251 rows and 2505000 columns (presolve time = 480s) ...
# Presolve removed 45837781 rows and 2505000 columns (presolve time = 485s) ...
# Presolve removed 45885536 rows and 2505000 columns (presolve time = 490s) ...
# Presolve removed 45926321 rows and 2505000 columns (presolve time = 495s) ...
# Presolve removed 45975841 rows and 2505000 columns (presolve time = 500s) ...
# Presolve removed 46039325 rows and 2505000 columns (presolve time = 505s) ...
# Presolve removed 46089827 rows and 2505000 columns (presolve time = 510s) ...
# Presolve removed 46149880 rows and 2505000 columns (presolve time = 515s) ...
# Presolve removed 46191904 rows and 2505000 columns (presolve time = 520s) ...
# Presolve removed 46249035 rows and 2505000 columns (presolve time = 525s) ...
# Presolve removed 46305532 rows and 2505000 columns (presolve time = 530s) ...
# Presolve removed 46351216 rows and 2505000 columns (presolve time = 535s) ...
# Presolve removed 46423300 rows and 2505000 columns (presolve time = 540s) ...
# Presolve removed 46475679 rows and 2505000 columns (presolve time = 545s) ...
# Presolve removed 46530580 rows and 2505000 columns (presolve time = 550s) ...
# Presolve removed 46591000 rows and 2505000 columns (presolve time = 555s) ...
# Presolve removed 46653504 rows and 2505000 columns (presolve time = 560s) ...
# Presolve removed 46718100 rows and 2505000 columns (presolve time = 565s) ...
# Presolve removed 46781499 rows and 2505000 columns (presolve time = 570s) ...
# Presolve removed 46841700 rows and 2505000 columns (presolve time = 575s) ...
# Presolve removed 46903298 rows and 2505000 columns (presolve time = 580s) ...
# Presolve removed 46981760 rows and 2505000 columns (presolve time = 585s) ...
# Presolve removed 47053620 rows and 2505000 columns (presolve time = 590s) ...
# Presolve removed 47137024 rows and 2505000 columns (presolve time = 595s) ...
# Presolve removed 47217913 rows and 2505000 columns (presolve time = 600s) ...
# Presolve removed 47294500 rows and 2505000 columns (presolve time = 605s) ...
# Presolve removed 47379765 rows and 2505000 columns (presolve time = 610s) ...
# Presolve removed 47458275 rows and 2505000 columns (presolve time = 615s) ...
# Presolve removed 47541163 rows and 2505000 columns (presolve time = 620s) ...
# Presolve removed 47625448 rows and 2505000 columns (presolve time = 625s) ...
# Presolve removed 47721530 rows and 2505000 columns (presolve time = 630s) ...
# Presolve removed 47806850 rows and 2505000 columns (presolve time = 635s) ...
# Presolve removed 47888848 rows and 2505000 columns (presolve time = 640s) ...
# Presolve removed 47954709 rows and 2505000 columns (presolve time = 645s) ...
# Presolve removed 48030186 rows and 2505000 columns (presolve time = 650s) ...
# Presolve removed 48117941 rows and 2505000 columns (presolve time = 655s) ...
# Presolve removed 48207347 rows and 2505000 columns (presolve time = 660s) ...
# Presolve removed 48287564 rows and 2505000 columns (presolve time = 665s) ...
# Presolve removed 48375770 rows and 2505000 columns (presolve time = 670s) ...
# Presolve removed 48476332 rows and 2505000 columns (presolve time = 675s) ...
# Presolve removed 48576738 rows and 2505000 columns (presolve time = 680s) ...
# Presolve removed 48675372 rows and 2505000 columns (presolve time = 685s) ...
# Presolve removed 48774317 rows and 2505000 columns (presolve time = 690s) ...
# Presolve removed 48882060 rows and 2505000 columns (presolve time = 695s) ...
# Presolve removed 48996912 rows and 2505000 columns (presolve time = 700s) ...
# Presolve removed 49111642 rows and 2505000 columns (presolve time = 705s) ...
# Presolve removed 49223830 rows and 2505000 columns (presolve time = 710s) ...
# Presolve removed 49333528 rows and 2505000 columns (presolve time = 715s) ...
# Presolve removed 49448393 rows and 2505000 columns (presolve time = 720s) ...
# Presolve removed 49567341 rows and 2505000 columns (presolve time = 725s) ...
# Presolve removed 49686838 rows and 2505000 columns (presolve time = 730s) ...
# Presolve removed 49807116 rows and 2505000 columns (presolve time = 735s) ...
# Presolve removed 49925680 rows and 2505000 columns (presolve time = 740s) ...
# Presolve removed 50049920 rows and 2505000 columns (presolve time = 745s) ...
# Presolve removed 50184355 rows and 2505000 columns (presolve time = 750s) ...
# Presolve removed 50256438 rows and 2505000 columns (presolve time = 755s) ...
# Presolve removed 50373996 rows and 2505000 columns (presolve time = 760s) ...
# Presolve removed 50502256 rows and 2505000 columns (presolve time = 765s) ...
# Presolve removed 50635560 rows and 2505000 columns (presolve time = 770s) ...
# Presolve removed 50721365 rows and 2505000 columns (presolve time = 775s) ...
# Presolve removed 50826628 rows and 2505000 columns (presolve time = 780s) ...
# Presolve removed 50949463 rows and 2505000 columns (presolve time = 785s) ...
# Presolve removed 51072490 rows and 2505000 columns (presolve time = 790s) ...
# Presolve removed 51146234 rows and 2505000 columns (presolve time = 795s) ...
# Presolve removed 51273296 rows and 2505000 columns (presolve time = 800s) ...
# Presolve removed 51405744 rows and 2505000 columns (presolve time = 805s) ...
# Presolve removed 51534856 rows and 2505000 columns (presolve time = 810s) ...
# Presolve removed 51659976 rows and 2505000 columns (presolve time = 815s) ...
# Presolve removed 51789276 rows and 2505000 columns (presolve time = 820s) ...
# Presolve removed 51916348 rows and 2505000 columns (presolve time = 825s) ...
# Presolve removed 51965500 rows and 2505000 columns (presolve time = 830s) ...
# Presolve removed 51965943 rows and 2505000 columns (presolve time = 835s) ...
# Presolve removed 51966807 rows and 2505000 columns (presolve time = 840s) ...
# Presolve removed 51968802 rows and 2505000 columns (presolve time = 845s) ...
# Presolve removed 51970269 rows and 2505000 columns (presolve time = 850s) ...
# Presolve removed 51974003 rows and 2505000 columns (presolve time = 855s) ...
# Presolve removed 51981792 rows and 2505000 columns (presolve time = 860s) ...
# Presolve removed 51982980 rows and 2505000 columns (presolve time = 865s) ...
# Presolve removed 51985660 rows and 2505000 columns (presolve time = 870s) ...
# Presolve removed 51988760 rows and 2505000 columns (presolve time = 875s) ...
# Presolve removed 51993464 rows and 2505000 columns (presolve time = 880s) ...
# Presolve removed 51998110 rows and 2505000 columns (presolve time = 885s) ...
# Presolve removed 52003020 rows and 2505000 columns (presolve time = 890s) ...
# Presolve removed 52010480 rows and 2505000 columns (presolve time = 895s) ...
# Presolve removed 52019240 rows and 2505000 columns (presolve time = 900s) ...
# Presolve removed 52020799 rows and 2505000 columns (presolve time = 905s) ...
# Presolve removed 52021388 rows and 2505000 columns (presolve time = 910s) ...
# Presolve removed 52021950 rows and 2505000 columns (presolve time = 915s) ...
# Presolve removed 52022508 rows and 2505000 columns (presolve time = 920s) ...
# Presolve removed 52023050 rows and 2505000 columns (presolve time = 925s) ...
# Presolve removed 52023458 rows and 2505000 columns (presolve time = 930s) ...
# Presolve removed 52024054 rows and 2505000 columns (presolve time = 935s) ...
# Presolve removed 52024500 rows and 2505000 columns (presolve time = 940s) ...
# Presolve removed 52024500 rows and 2505000 columns (presolve time = 945s) ...
# Presolve removed 52025246 rows and 2505000 columns (presolve time = 950s) ...
# Presolve removed 52026601 rows and 2505000 columns (presolve time = 955s) ...
# Presolve removed 52027434 rows and 2505000 columns (presolve time = 960s) ...
# Presolve removed 52028754 rows and 2505000 columns (presolve time = 965s) ...
# Presolve removed 52046500 rows and 2505000 columns (presolve time = 970s) ...
# Presolve removed 52046500 rows and 2505000 columns
# Presolve time: 971.67s
#
# Explored 0 nodes (0 simplex iterations) in 1016.15 seconds
# Thread count was 1 (of 8 available processors)
#
# Solution count 1: 548.2
#
# Time limit reached
# Best objective 5.482000000000e+02, best bound -, gap -
# Warning: variables 0 and 251000 have the same name "y[0]"
# Warning: default variable names used to write solution file
# Changed value of parameter TimeLimit to 1000.0
#    Prev: 1e+100  Min: 0.0  Max: 1e+100  Default: 1e+100
# Optimize a model with 60890500 rows, 2761000 columns and 119779500 nonzeros
# Variable types: 0 continuous, 2761000 integer (2761000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+02]
#   Objective range  [2e-01, 1e+00]
#   Bounds range     [1e+00, 1e+00]

# %% [markdown]
# # 解の図示

# %% [markdown]
# ## ビンごとに辞書に登録

# %%
node_dict = {}
for Item,Bin in ans_x:
    if ans_x[Item,Bin] == 1:
        Item = int(Item)
        Bin = int(Bin)
        try:
            node_dict[Bin] = node_dict[Bin] + [Item]
        except:
            node_dict[Bin] = [Item]
        
node_dict
# Out:
# {0: [0]}

# %%
node_dict = {}
for Item,Bin in ans_x:
    if ans_x[Item,Bin] == 1:
        Item = int(Item)
        Bin = int(Bin)
        node_dict.setdefault(Bin,[])
        node_dict[Bin] = node_dict[Bin] + [Item]
    
node_dict
# Out:
# {0: [0]}

# %%
node_dict = {}
for Item,Bin in ans_x:
    if ans_x[Item,Bin] == 1:
        Item = int(Item)
        Bin = int(Bin)
        node_dict[Bin] = node_dict.setdefault(Bin,[]) + [Item]
    
node_dict
# Out:
# {0: [0]}

# %% [markdown]
# ## 描画

# %%
import networkx as nx
import matplotlib
import matplotlib.pyplot as plt
matplotlib.use("Agg")
import random
G = nx.Graph()

for v in range(n): # グラフにノードを追加
    G.add_node(v)
    
pos = nx.spring_layout(G, k=1)
plt.figure(figsize=(10,10))


for l in node_dict.values():
    node_color = random.sample(matplotlib.colors.cnames.keys(),1)
    nx.draw_networkx_nodes(G, pos, nodelist=[i for i in l], node_color=node_color, alpha=0.6, node_size=4000)
    nx.draw_networkx_labels(G, pos, font_size=50, font_family="Yu Gothic", font_weight="bold")
    
# %matplotlib inline
plt.show()
#plt.savefig("figure.png")

# %%
import networkx as nx
import matplotlib
import matplotlib.pyplot as plt
matplotlib.use("Agg")
import random
G = nx.Graph()

for v in range(n): # グラフにノードを追加
    G.add_node(v)
    
plt.figure(figsize=(10,10))

for b in range(n):
    node_color = random.sample(matplotlib.colors.cnames.keys(),1)
    for i in range(n):
        if ans_x[str(i),str(b)]==1:
            nx.draw_networkx_nodes(G, pos, nodelist=[i],node_color=node_color, alpha=0.6, node_size=4000)
            nx.draw_networkx_labels(G, pos, font_size=50, font_family="Yu Gothic", font_weight="bold")

plt.show()
#plt.savefig("figure.png")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-19-abc397358711> in <module>
#      14     node_color = random.sample(matplotlib.colors.cnames.keys(),1)
#      15     for i in range(n):
# ---> 16         if ans_x[str(i),str(b)]==1:
#      17             nx.draw_networkx_nodes(G, pos, nodelist=[i],node_color=node_color, alpha=0.6, node_size=4000)
#      18             nx.draw_networkx_labels(G, pos, font_size=50, font_family="Yu Gothic", font_weight="bold")
#
# KeyError: ('10', '0')
# findfont: Font family ['Yu Gothic'] not found. Falling back to DejaVu Sans.

# %%
import networkx as nx
import matplotlib
import matplotlib.pyplot as plt
matplotlib.use("Agg")
import random
G = nx.Graph()

for v in range(n): # グラフにノードを追加
    G.add_node(v)
    
plt.figure(figsize=(10,10))

for b in map(lambda x:x[1],ans_x.keys()):
    node_color = random.sample(matplotlib.colors.cnames.keys(),1)
    for i in list(set(map(lambda x:x[0],ans_x.keys()))):
        if ans_x[str(i),str(b)]==1:
            nx.draw_networkx_nodes(G, pos, nodelist=[int(i)],node_color=node_color, alpha=0.6, node_size=4000)
            nx.draw_networkx_labels(G, pos, font_size=50, font_family="Yu Gothic", font_weight="bold")

plt.show()
#plt.savefig("figure.png")
