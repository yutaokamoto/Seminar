# %% [markdown]
# # 配送計画モデルVRP_D_1M1_TWの実行例
# 使用可能な機能：距離，容量制約1M1, 時間枠
#
# ## ランダムな問題例の作成

# %%
n=50 #客数

import random
random.seed(1)

C={} # 客の座標を保存する辞書
TW={} # 客の時間枠を保存する辞書
demand={} # 客の要求量(正の値は集荷，負の値は配達)
S={} # 客のサービス時間

for i in range(n):
    name="c"+str(i)
    x=random.randint(-500,500)
    y=random.randint(-500,500)
    C[name]=(x,y)
    e=random.randint(0,3000)
    l=e+random.randint(0,4000-e)
    TW[name]=(e,l)
    if random.randint(0,1) == 0:
        demand[name]=random.randint(1,5)
    else:
        demand[name]=random.randint(-5,-1)
    S[name]=random.randint(10,20)
        
C["depot"]=(0,0)

# %%
print("Customer",C)
print("Time Window",TW)
print("Demand",demand)
print("Service Time",S)
# Out:
# Customer {'c0': (-363, 82), 'c1': (-17, 167), 'c2': (414, 355), 'c3': (238, 321), 'c4': (-478, -474), 'c5': (-279, 492), 'c6': (66, -262), 'c7': (448, -478), 'c8': (241, 380), 'c9': (19, 349), 'c10': (496, 403), 'c11': (-9, -252), 'c12': (403, 219), 'c13': (20, -390), 'c14': (250, -470), 'c15': (92, -97), 'c16': (-488, 289), 'c17': (-148, 475), 'c18': (61, 123), 'c19': (31, 296), 'c20': (390, -127), 'c21': (-4, 332), 'c22': (53, 138), 'c23': (323, -265), 'c24': (316, 371), 'c25': (-37, -486), 'c26': (-311, -148), 'c27': (40, 474), 'c28': (219, -171), 'c29': (-105, -149), 'c30': (421, 247), 'c31': (-482, -94), 'c32': (194, -64), 'c33': (-272, 36), 'c34': (175, 146), 'c35': (396, -452), 'c36': (261, -338), 'c37': (399, 370), 'c38': (-325, 347), 'c39': (-145, -399), 'c40': (4, -394), 'c41': (-483, -167), 'c42': (-295, 378), 'c43': (-282, -228), 'c44': (436, 403), 'c45': (-434, 242), 'c46': (432, 51), 'c47': (361, -239), 'c48': (-260, 388), 'c49': (64, 288), 'depot': (0, 0)}
# Time Window {'c0': (258, 1302), 'c1': (1554, 2413), 'c2': (1596, 3368), 'c3': (937, 3358), 'c4': (2660, 3768), 'c5': (1728, 1846), 'c6': (1415, 2360), 'c7': (1704, 3983), 'c8': (1214, 1709), 'c9': (2745, 3133), 'c10': (2045, 3778), 'c11': (1655, 3352), 'c12': (2762, 3529), 'c13': (670, 2803), 'c14': (1922, 2100), 'c15': (2650, 2998), 'c16': (817, 3027), 'c17': (2366, 3089), 'c18': (2987, 2992), 'c19': (2299, 2719), 'c20': (2334, 3469), 'c21': (1461, 3158), 'c22': (2508, 3186), 'c23': (2602, 2964), 'c24': (1045, 1177), 'c25': (1151, 2173), 'c26': (1189, 1473), 'c27': (688, 3377), 'c28': (2033, 3003), 'c29': (1724, 2494), 'c30': (2089, 2517), 'c31': (599, 743), 'c32': (2231, 3935), 'c33': (2656, 2718), 'c34': (1746, 1986), 'c35': (1254, 1543), 'c36': (1704, 2737), 'c37': (155, 2574), 'c38': (2883, 3925), 'c39': (842, 3190), 'c40': (2727, 3525), 'c41': (2507, 3330), 'c42': (1342, 3649), 'c43': (2762, 2959), 'c44': (2814, 3908), 'c45': (165, 511), 'c46': (872, 1969), 'c47': (1507, 2894), 'c48': (2473, 3937), 'c49': (427, 1740)}
# Demand {'c0': 4, 'c1': 4, 'c2': 4, 'c3': 3, 'c4': 4, 'c5': 4, 'c6': 4, 'c7': 2, 'c8': -1, 'c9': -3, 'c10': -1, 'c11': 3, 'c12': 4, 'c13': -3, 'c14': -1, 'c15': 5, 'c16': 4, 'c17': -3, 'c18': -1, 'c19': -5, 'c20': 5, 'c21': -5, 'c22': -1, 'c23': 1, 'c24': 1, 'c25': -5, 'c26': 2, 'c27': -3, 'c28': 1, 'c29': -5, 'c30': -5, 'c31': 4, 'c32': 5, 'c33': -1, 'c34': -4, 'c35': 3, 'c36': 1, 'c37': 5, 'c38': 4, 'c39': -1, 'c40': -1, 'c41': -5, 'c42': 3, 'c43': -1, 'c44': -1, 'c45': 2, 'c46': -1, 'c47': -5, 'c48': -4, 'c49': 4}
# Service Time {'c0': 17, 'c1': 10, 'c2': 14, 'c3': 10, 'c4': 20, 'c5': 17, 'c6': 14, 'c7': 20, 'c8': 16, 'c9': 19, 'c10': 10, 'c11': 18, 'c12': 20, 'c13': 17, 'c14': 19, 'c15': 13, 'c16': 18, 'c17': 20, 'c18': 12, 'c19': 17, 'c20': 16, 'c21': 18, 'c22': 10, 'c23': 18, 'c24': 10, 'c25': 19, 'c26': 14, 'c27': 17, 'c28': 14, 'c29': 14, 'c30': 13, 'c31': 18, 'c32': 17, 'c33': 15, 'c34': 13, 'c35': 14, 'c36': 18, 'c37': 17, 'c38': 13, 'c39': 13, 'c40': 17, 'c41': 12, 'c42': 16, 'c43': 15, 'c44': 13, 'c45': 12, 'c46': 18, 'c47': 14, 'c48': 19, 'c49': 11}

# %% [markdown]
# ## 車両数と容量の設定

# %%
m=7 # number of vehicles
capacity=30 # capacity of vehicle

# %% [markdown]
# ## 問題例の描画

# %%
import networkx as nx
import matplotlib.pyplot as plt
G=nx.DiGraph()
fig=plt.figure(figsize=(7,7))

G=nx.DiGraph()
nx.draw_networkx(G,pos=C,nodelist=[i for i in C if i != "depot"],node_color="y",node_size=50,with_labels=True,edge_color="k",width=1)
nx.draw_networkx(G,pos=C,nodelist=["depot"],node_color="blue",node_shape='s',alpha=0.5,node_size=100,with_labels=True,edge_color="k",width=1)

plt.show()

# %%
def distance(t1,t2):
    return ((t1[0]-t2[0])**2+(t1[1]-t2[1])**2)**(0.5)

# %% [markdown]
# ## 配送計画ソルバーの実行

# %%
import sys
sys.path.append('..')

from vrplib.vrp_d_1m1_t_model import *

model = Model("example-vrp_d_1m1_tw") # モデルインスタンスの生成

# 客インスタンスの生成
for i in C:
    if i == "depot":
        continue
    model += Customer(i,demand=(demand[i],),timewindow=TW[i],servicetime=S[i])

# 車両インスタンスの生成
for k in range(m):
    model += Vehicle("v"+str(k),capacity=(capacity,))
    
# 枝インスタンスの生成
for i in C:
    for j in C:
        if i!=j:
            dist = time = distance(C[i],C[j])
            model += Edge(i,j,dist,time)

# 最適化の実行
obj=model.optimize(IterLimit=1,TimeLimit=11,Verbose=True,OutputFlag=False)

# 得られた解の表示
print("objective value =",obj)
for v in model.vehiclesL:
    print()
    print(v)
    print(list(map(lambda x:x.name,v.routing[1:-1])))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-6-74f6cbfc311c> in <module>
#       2 sys.path.append('..')
#       3
# ----> 4 from vrplib.vrp_d_1m1_t_model import *
#       5
#       6 model = Model("example-vrp_d_1m1_tw") # モデルインスタンスの生成
#
# ModuleNotFoundError: No module named 'vrplib'

# %% [markdown]
# ## 得られた解の描画

# %%
import networkx as nx
import matplotlib.pyplot as plt
G=nx.DiGraph()
for v in model.vehiclesL:
    prev=None
    for j in v.routing[1:-1]:
        if prev == None:                
            G.add_edge("depot",j.name)
        else:
            G.add_edge(prev.name,j.name)
        prev= j 
    G.add_edge(prev.name,"depot")
    
fig=plt.figure(figsize=(9,9))    
nx.draw_networkx(G,pos=C,nodelist=[i for i in G.nodes() if i != "depot"],node_color="yellow",node_size=50,with_labels=True,edge_color="k",width=1)
nx.draw_networkx(G,pos=C,nodelist=["depot"],node_color="blue",node_shape='s',alpha=0.5,node_size=50,with_labels=True,edge_color="k",width=1)
plt.show()
# Out:
# /miniconda3/lib/python3.7/site-packages/networkx/drawing/nx_pylab.py:579: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if not cb.iterable(width):
# /miniconda3/lib/python3.7/site-packages/networkx/drawing/nx_pylab.py:676: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if cb.iterable(node_size):  # many node sizes

# %% [markdown]
# ## 得られた解の詳細な情報

# %%
for v in model.vehiclesL:
    print()
    print(v)
    keys=v.routing[1].stat.keys()
    print("customer,",", ".join(keys))
    for c in v.routing[1:-1]:
        print(c.name+", ",end="")
        for k in keys:
            print(c.stat[k],end=",")
        print()
# Out:
# Vehicle v0: {'capacity': (30,)}
# 1792.878894 = {'distance': 1792.878894, 'freight_1M1': 0.0, 'timecost': 0.0}
# customer, distance, freight_1M1_0, arrival, service, departure, timecost, travelcost
# c3, 399.606056,3.000000,399.606056,937.000000,947.000000,0.000000,0.000000,
# c24, 492.255935,1.000000,1039.649879,1045.000000,1055.000000,0.000000,0.000000,
# c8, 567.794004,-1.000000,1130.538070,1214.000000,1230.000000,0.000000,0.000000,
# c30, 791.599724,-5.000000,1453.805719,2089.000000,2102.000000,0.000000,0.000000,
# c2, 899.826338,4.000000,2210.226614,2210.226614,2224.226614,0.000000,0.000000,
# c37, 921.039541,5.000000,2245.439818,2245.439818,2262.439818,0.000000,0.000000,
# c44, 970.617762,-1.000000,2312.018039,2814.000000,2827.000000,0.000000,0.000000,
# c10, 1030.617762,-1.000000,2887.000000,2887.000000,2897.000000,0.000000,0.000000,
# c12, 1236.785170,4.000000,3103.167408,3103.167408,3123.167408,0.000000,0.000000,
# c32, 1588.594778,5.000000,3474.977015,3474.977015,3491.977015,0.000000,0.000000,
#
# Vehicle v1: {'capacity': (30,)}
# 1630.963798 = {'distance': 1630.963798, 'freight_1M1': 0.0, 'timecost': 0.0}
# customer, distance, freight_1M1_0, arrival, service, departure, timecost, travelcost
# c49, 295.025423,4.000000,295.025423,427.000000,438.000000,0.000000,0.000000,
# c27, 482.567418,-3.000000,625.541995,688.000000,705.000000,0.000000,0.000000,
# c5, 802.074851,4.000000,1024.507433,1728.000000,1745.000000,0.000000,0.000000,
# c17, 934.173299,-3.000000,1877.098448,2366.000000,2386.000000,0.000000,0.000000,
# c48, 1075.993608,-4.000000,2527.820309,2527.820309,2546.820309,0.000000,0.000000,
# c42, 1112.394158,3.000000,2583.220858,2583.220858,2599.220858,0.000000,0.000000,
# c38, 1155.533467,4.000000,2642.360168,2883.000000,2896.000000,0.000000,0.000000,
#
# Vehicle v2: {'capacity': (30,)}
# 738.474086 = {'distance': 738.474086, 'freight_1M1': 0.0, 'timecost': 0.0}
# customer, distance, freight_1M1_0, arrival, service, departure, timecost, travelcost
# c1, 167.863039,4.000000,167.863039,1554.000000,1564.000000,0.000000,0.000000,
# c19, 305.503876,-5.000000,1701.640837,2299.000000,2316.000000,0.000000,0.000000,
# c9, 359.845389,-3.000000,2370.341513,2745.000000,2764.000000,0.000000,0.000000,
# c21, 388.446088,-5.000000,2792.600699,2792.600699,2810.600699,0.000000,0.000000,
# c22, 590.646484,-1.000000,3012.801095,3012.801095,3022.801095,0.000000,0.000000,
#
# Vehicle v3: {'capacity': (30,)}
# 2465.911111 = {'distance': 2465.911111, 'freight_1M1': 0.0, 'timecost': 0.0}
# customer, distance, freight_1M1_0, arrival, service, departure, timecost, travelcost
# c46, 435.000000,-1.000000,435.000000,872.000000,890.000000,0.000000,0.000000,
# c35, 939.286625,3.000000,1394.286625,1394.286625,1408.286625,0.000000,0.000000,
# c7, 997.424392,2.000000,1466.424392,1704.000000,1724.000000,0.000000,0.000000,
# c14, 1195.585943,-1.000000,1922.161550,1922.161550,1941.161550,0.000000,0.000000,
# c36, 1328.043483,1.000000,2073.619091,2073.619091,2091.619091,0.000000,0.000000,
# c23, 1423.819263,1.000000,2187.394870,2602.000000,2620.000000,0.000000,0.000000,
# c47, 1469.862720,-5.000000,2666.043458,2666.043458,2680.043458,0.000000,0.000000,
# c20, 1585.556281,5.000000,2795.737018,2795.737018,2811.737018,0.000000,0.000000,
# c28, 1762.126381,1.000000,2988.307118,2988.307118,3002.307118,0.000000,0.000000,
# c40, 2071.890807,-1.000000,3312.071545,3312.071545,3329.071545,0.000000,0.000000,
#
# Vehicle v4: {'capacity': (30,)}
# 481.498018 = {'distance': 481.498018, 'freight_1M1': 0.0, 'timecost': 0.0}
# customer, distance, freight_1M1_0, arrival, service, departure, timecost, travelcost
# c34, 227.905682,-4.000000,227.905682,1746.000000,1759.000000,0.000000,0.000000,
# c18, 344.202716,-1.000000,1875.297033,2987.000000,2999.000000,0.000000,0.000000,
#
# Vehicle v5: {'capacity': (30,)}
# 2366.733231 = {'distance': 2366.733231, 'freight_1M1': 0.0, 'timecost': 0.0}
# customer, distance, freight_1M1_0, arrival, service, departure, timecost, travelcost
# c45, 496.910455,2.000000,496.910455,496.910455,508.910455,0.000000,0.000000,
# c16, 568.499560,4.000000,580.499560,817.000000,835.000000,0.000000,0.000000,
# c0, 810.313538,4.000000,1076.813978,1076.813978,1093.813978,0.000000,0.000000,
# c33, 912.279219,-1.000000,1195.779659,2656.000000,2671.000000,0.000000,0.000000,
# c43, 1176.468545,-1.000000,2935.189326,2935.189326,2950.189326,0.000000,0.000000,
# c41, 1386.520919,-5.000000,3160.241700,3160.241700,3172.241700,0.000000,0.000000,
# c4, 1693.561633,4.000000,3479.282414,3479.282414,3499.282414,0.000000,0.000000,
#
# Vehicle v6: {'capacity': (30,)}
# 1911.577975 = {'distance': 1911.577975, 'freight_1M1': 0.0, 'timecost': 0.0}
# customer, distance, freight_1M1_0, arrival, service, departure, timecost, travelcost
# c31, 491.080441,4.000000,491.080441,599.000000,617.000000,0.000000,0.000000,
# c26, 670.404171,2.000000,796.323730,1189.000000,1203.000000,0.000000,0.000000,
# c39, 971.331073,-1.000000,1503.926901,1503.926901,1516.926901,0.000000,0.000000,
# c25, 1110.014164,-5.000000,1655.609993,1655.609993,1674.609993,0.000000,0.000000,
# c13, 1221.660929,-3.000000,1786.256758,1786.256758,1803.256758,0.000000,0.000000,
# c6, 1357.675634,4.000000,1939.271463,1939.271463,1953.271463,0.000000,0.000000,
# c11, 1433.339364,3.000000,2028.935193,2028.935193,2046.935193,0.000000,0.000000,
# c29, 1574.140642,-5.000000,2187.736471,2187.736471,2201.736471,0.000000,0.000000,
# c15, 1777.888035,5.000000,2405.483864,2650.000000,2663.000000,0.000000,0.000000,
